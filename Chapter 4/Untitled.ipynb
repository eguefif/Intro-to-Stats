# %%
import pandas as pd
import seaborn as sns

df = pd.read_csv('Ch4/Population_growth_2010.txt', sep='\t')

# %%
sns.boxplot(data=df, x='Region', y='Percent_Change')
# Out:
# <AxesSubplot:xlabel='Region', ylabel='Percent_Change'>

# %% [markdown]
# Sw region has a bigger growth than the NEMW. Is is also more spread.

# %%
df = pd.read_csv('Ch4/Industrial_experiment.txt', sep='\t')
df = df[df['Distance'] < 0.8]
df1 = df[df['Speed'] == 'Fast']
df2 = df[df['Speed'] == 'Slow']
df1.plot(kind='hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df2.plot(kind='hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
sns.boxplot(data=df, x='Speed', y='Distance')
# Out:
# <AxesSubplot:xlabel='Speed', ylabel='Distance'>

# %%
df1.describe()
# Out:
#         Distance
# count  10.000000
# mean    0.000102
# std     0.000001
# min     0.000100
# 25%     0.000101
# 50%     0.000102
# 75%     0.000102
# max     0.000104

# %%
df2.describe()
# Out:
#         Distance
# count  10.000000
# mean    0.097647
# std     0.308481
# min     0.000094
# 25%     0.000096
# 50%     0.000097
# 75%     0.000098
# max     0.975600

# %%
df.describe()
# Out:
#         Distance
# count  20.000000
# mean    0.048874
# std     0.218129
# min     0.000094
# 25%     0.000097
# 50%     0.000100
# 75%     0.000102
# max     0.975600

# %% [markdown]
# There was an outlier in the distribution that I remove. It was mostlikly an error. The distance was way to high.
#
# The fastest speed perform better. They both share the same distribution. THe fast is a bit skewe to th right.
